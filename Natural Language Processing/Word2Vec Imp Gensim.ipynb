# %% [markdown]
# ### Word2Vec Implementation using Gensim

# %%
# !pip install gensim

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api

# %%
wv = api.load('word2vec-google-news-300')
vec_king = wv['king']

# %%
wv['cricket']
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\programming\Machine Learning, Data Science by Krish Naik\SpamClassifier-master\smsspamcollection\SMSSpamCollection", sep='\t',names=['labels','message'])

# %%
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()
import re
import nltk
from nltk.corpus import stopwords

# %%
corpus = []
for i in range(0,len(df)):
    review = re.sub('[^a-zA-Z]',' ',df['message'][i])
    review = review.lower()
    review = review.split()
    review=[lem.lemmatize(word)for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
for i, j, k in zip(list(map(len, corpus)), corpus, df['message']):
    if i < 1:
        # your code here
        print(i, j, k)
# Out:
# 0  What you doing?how are you?
# 0  Where @
# 0  645
# 0  Can a not?
# 0  :)
# 0  What you doing?how are you?
# 0  :( but your not here....
# 0  :-) :-)

# %%
corpus
# Out:
# ['go jurong point crazy available bugis n great world la e buffet cine got amore wat',
#  'ok lar joking wif u oni',
#  'free entry wkly comp win fa cup final tkts st may text fa receive entry question std txt rate c apply',
#  'u dun say early hor u c already say',
#  'nah think go usf life around though',
#  'freemsg hey darling week word back like fun still tb ok xxx std chgs send rcv',
#  'even brother like speak treat like aid patent',
#  'per request melle melle oru minnaminunginte nurungu vettam set callertune caller press copy friend callertune',
#  'winner valued network customer selected receivea prize reward claim call claim code kl valid hour',
#  'mobile month u r entitled update latest colour mobile camera free call mobile update co free',
#  'gonna home soon want talk stuff anymore tonight k cried enough today',
#  'six chance win cash pound txt csh send cost p day day tsandcs apply reply hl info',
# ...

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
words = []
for sent in corpus:
    sent_token = sent_tokenize(sent)
    for sent in sent_token:
        words.append(simple_preprocess(sent))

# %%
words
# Out:
# [['go',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'wkly',
#   'comp',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply'],
#  ['dun', 'say', 'early', 'hor', 'already', 'say'],
#  ['nah', 'think', 'go', 'usf', 'life', 'around', 'though'],
#  ['freemsg',
#   'hey',
#   'darling',
#   'week',
#   'word',
#   'back',
#   'like',
#   'fun',
#   'still',
#   'tb',
#   'ok',
#   'xxx',
#   'std',
#   'chgs',
#   'send',
#   'rcv'],
#  ['even', 'brother', 'like', 'speak', 'treat', 'like', 'aid', 'patent'],
#  ['per',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertune',
#   'caller',
# ...

# %%
import gensim

# %%
model = gensim.models.Word2Vec(words)

# %%
model.wv.index_to_key
# Out:
# ['call',
#  'get',
#  'ur',
#  'gt',
#  'lt',
#  'go',
#  'day',
#  'ok',
#  'free',
#  'know',
#  'come',
#  'like',
#  'time',
#  'good',
#  'got',
#  'love',
#  'text',
#  'want',
#  'send',
#  'need',
#  'one',
#  'txt',
#  'today',
#  'going',
#  'stop',
#  'home',
#  'lor',
#  'sorry',
#  'see',
#  'still',
#  'mobile',
#  'take',
#  'back',
#  'da',
#  'reply',
#  'dont',
#  'think',
#  'tell',
#  'week',
#  'phone',
#  'hi',
#  'new',
#  'please',
#  'later',
#  'pls',
#  'co',
#  'msg',
#  'min',
#  'dear',
#  'night',
#  'make',
#  'message',
#  'well',
#  'say',
#  'thing',
#  'much',
#  'claim',
#  'hope',
#  'great',
#  'oh',
#  'hey',
#  'give',
#  'number',
#  'happy',
#  'friend',
#  'wat',
#  'work',
#  'way',
#  'yes',
#  'www',
#  'prize',
#  'let',
#  'right',
#  'tomorrow',
#  'already',
#  'tone',
#  'ask',
#  'said',
#  'win',
#  'cash',
#  'amp',
#  'life',
#  'yeah',
#  'im',
#  'really',
#  'meet',
#  'babe',
#  'find',
#  'miss',
#  'morning',
#  'last',
# ...

# %%
model.corpus_count
# Out:
# 5564

# %%
model.wv.similar_by_word('good')
# Out:
# [('give', 0.9995920658111572),
#  ('day', 0.9995762705802917),
#  ('night', 0.9995531439781189),
#  ('today', 0.9995388388633728),
#  ('much', 0.9995387196540833),
#  ('get', 0.9995336532592773),
#  ('got', 0.9995266199111938),
#  ('going', 0.9995211362838745),
#  ('go', 0.9995197057723999),
#  ('said', 0.9995188117027283)]

# %%
def avg_word2vec(doc):

    return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key])

# %%
# !pip install tqdm

# %%
from tqdm import tqdm

# %%
X = []
for i in tqdm(range(len(words))):
    X.append(avg_word2vec(words[i]))
# Out:
#   0%|          | 0/5564 [00:00<?, ?it/s]c:\Users\hp\anaconda3\envs\myenv\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\hp\anaconda3\envs\myenv\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 5564/5564 [00:00<00:00, 7171.46it/s]

# %%
X, len(X)
# Out:
# ([-0.0027986865,
#   -0.0025447414,
#   -0.0024597934,
#   -0.003554524,
#   -0.002692633,
#   -0.0026658946,
#   -0.003442409,
#   -0.0021638935,
#   -0.0030142453,
#   -0.0034107822,
#   -0.0029732643,
#   -0.0036547885,
#   -0.0032820317,
#   -0.002201195,
#   -0.0017467993,
#   -0.0023383126,
#   -0.0030327947,
#   -0.0026583627,
#   -0.003458035,
#   -0.002421748,
#   -0.0019265747,
#   -0.002446096,
#   -0.0027371787,
#   -0.0035118745,
#   -0.0031344492,
#   -0.001802655,
#   -0.0036168399,
#   -0.0021420703,
#   -0.003840401,
#   -0.0036256155,
#   -0.0031059685,
#   -0.0035950982,
#   -0.004287631,
#   -0.00036929775,
#   -0.002952897,
#   -0.0033960624,
#   -0.0021303678,
#   -0.0035444538,
#   -0.0031514168,
#   -0.00316651,
#   -0.0030871457,
#   -0.0034313872,
#   -0.0037818255,
#   -0.0010788194,
#   -0.0034116993,
#   -0.0038503166,
#   -0.0029507414,
#   -0.0032460324,
#   -0.0023589544,
#   -0.0022568514,
#   -0.0034730553,
#   -0.0021633164,
#   -0.0021518455,
# ...

# %%
X_new = np.array(X)

# %%
X_new, X_new.shape
# Out:
# (array([-0.00279869, -0.00254474, -0.00245979, ..., -0.00050442,
#         -0.00271203, -0.00280458]),
#  (5564,))

# %%
y = df[list(map(lambda x: len(x)> 0, corpus))]
y = pd.get_dummies(y['labels'])
y = y.iloc[:,0].values

# %%
y.shape
# Out:
# (5564,)

# %%
X[0].reshape(1,-1).shape
# Out:
# (1, 1)

# %%
new = pd.concat([pd.DataFrame(X[i].reshape(1, -1)) for i in range(len(X))], ignore_index=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10928\1218782617.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new = pd.concat([pd.DataFrame(X[i].reshape(1, -1)) for i in range(len(X))], ignore_index=True)

# %%
new.shape
# Out:
# (5564, 1)

# %%
new.head()
# Out:
#           0
# 0 -0.002799
# 1 -0.002545
# 2 -0.002460
# 3 -0.003555
# 4 -0.002693
